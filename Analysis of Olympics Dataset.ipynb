# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
athletes = pd.read_csv('C:/Users/DELL/Downloads/olympics/athlete_events.csv')
regions = pd.read_csv('C:/Users/DELL/Downloads/olympics/noc_regions.csv')

# %%
athletes.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
athletes_pra=athletes.merge(regions,how= 'left',on='NOC')
athletes_pra.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
athletes_pra.shape
# Out:
# (271116, 17)

# %%
# for column names consistent

athletes_pra.rename(columns={'region':"Region","notes":"Notes"},inplace=True)

# %%
athletes_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       Region Notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
athletes_pra.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
#  15  Region  270746 non-null  object
#  16  Notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 37.2+ MB

# %%
athletes_pra.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
nan_values = athletes_pra.isna()
nan_columns = nan_values.any()
nan_columns
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# Region     True
# Notes      True
# dtype: bool

# %%
athletes_pra.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# Region       370
# Notes     266077
# dtype: int64

# %%
# country detail
athletes_pra.query('Team =="Pakistan"').head(8)
# Out:
#       ID            Name Sex   Age  Height  Weight      Team  NOC  \
# 233  111    Aqarab Abbas   M  22.0   190.0    88.0  Pakistan  PAK
# 237  115    Ghulam Abbas   M  24.0   181.0    74.0  Pakistan  PAK
# 245  121  Muhammad Abbas   M  23.0   168.0    55.0  Pakistan  PAK
# 247  123    Sohail Abbas   M  25.0   178.0    80.0  Pakistan  PAK
# 248  123    Sohail Abbas   M  29.0   178.0    80.0  Pakistan  PAK
# 249  123    Sohail Abbas   M  37.0   178.0    80.0  Pakistan  PAK
# 253  127  Shakeel Abbasi   M  20.0   165.0    60.0  Pakistan  PAK
# 254  127  Shakeel Abbasi   M  24.0   165.0    60.0  Pakistan  PAK
#
#            Games  Year  Season       City          Sport  \
# 233  1996 Summer  1996  Summer    Atlanta      Athletics
# 237  1992 Summer  1992  Summer  Barcelona      Athletics
# 245  2010 Winter  2010  Winter  Vancouver  Alpine Skiing
# 247  2000 Summer  2000  Summer     Sydney         Hockey
# 248  2004 Summer  2004  Summer     Athina         Hockey
# ...

# %%
athletes_pra.query('Team =="France"').head(8)
# Out:
#      ID                                Name Sex   Age  Height  Weight    Team  \
# 98   34  Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0    76.0  France
# 145  52                       Patrick Abada   M  22.0   189.0    80.0  France
# 149  56                          Ren Abadie   M  21.0     NaN     NaN  France
# 150  56                          Ren Abadie   M  21.0     NaN     NaN  France
# 173  73                           Luc Abalo   M  23.0   182.0    86.0  France
# 174  73                           Luc Abalo   M  27.0   182.0    86.0  France
# 175  73                           Luc Abalo   M  31.0   182.0    86.0  France
# 199  93                      Jol Marc Abati   M  34.0   190.0    85.0  France
#
#      NOC        Games  Year  Season            City      Sport  \
# 98   FRA  2012 Summer  2012  Summer          London  Athletics
# 145  FRA  1976 Summer  1976  Summer        Montreal  Athletics
# 149  FRA  1956 Summer  1956  Summer       Melbourne    Cycling
# ...

# %%
athletes_pra.query('Team =="India"').head(8)
# Out:
#       ID                             Name Sex   Age  Height  Weight   Team  \
# 505  281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 506  281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 895  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 896  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 897  512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
# 898  512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
# 899  512  Shiny Kurisingal Abraham-Wilson   F  27.0   167.0    53.0  India
# 900  512  Shiny Kurisingal Abraham-Wilson   F  31.0   167.0    53.0  India
#
#      NOC        Games  Year  Season         City      Sport  \
# 505  IND  1928 Summer  1928  Summer    Amsterdam  Athletics
# 506  IND  1928 Summer  1928  Summer    Amsterdam  Athletics
# 895  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# ...

# %%
# Top countries participation
top_18_countries = athletes_pra.Team.value_counts().sort_values(ascending=False).head(18)
top_18_countries
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Poland            6143
# Switzerland       5844
# Netherlands       5718
# Soviet Union      5535
# Finland           5379
# Spain             5224
# China             4975
# Russia            4922
# Name: Team, dtype: int64

# %%
# plot for top 18 countries
plt.figure(figsize=(20,15))
plt.title('Total participation by Country')
sns.barplot(x=top_18_countries.index,y=top_18_countries,palette= 'Set2');

# %%
# weight distribution of participants

plt.figure(figsize=(20,10))
plt.title("Weight distribution of the athletes")
plt.xlabel('Weight (kg)')
plt.ylabel('Number of participants')
plt.hist(athletes_df.Weight,bins= np.arange(50,150,2),color='green',edgecolor='red');

# %%
winter_sports = athletes_pra[athletes_pra.Season == 'Winter'].Sport.unique()
winter_sports
# Out:
# array(['Speed Skating', 'Cross Country Skiing', 'Ice Hockey', 'Biathlon',
#        'Alpine Skiing', 'Luge', 'Bobsleigh', 'Figure Skating',
#        'Nordic Combined', 'Freestyle Skiing', 'Ski Jumping', 'Curling',
#        'Snowboarding', 'Short Track Speed Skating', 'Skeleton',
#        'Military Ski Patrol', 'Alpinism'], dtype=object)

# %%
summer_sports = athletes_pra[athletes_pra.Season == 'Summer'].Sport.unique()
summer_sports
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
# total no. of male and female

gender_counts= athletes_pra.Sex.value_counts()
gender_counts
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.title('Gender Distribution')
plt.pie(gender_counts,labels=gender_counts.index,autopct='%1.2f%%',startangle=150,shadow="True");

# %%
# total number of medel 
athletes_pra.Medal.value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
# total male participants in each olympics
male_participants = athletes_pra[(athletes_pra.Sex =='M') & (athletes_pra.Season=='Winter')][['Sex','Year']]
male_participants= male_participants.groupby('Year').count().reset_index()
male_participants.tail()
# Out:
#     Year   Sex
# 17  1998  2221
# 18  2002  2527
# 19  2006  2625
# 20  2010  2555
# 21  2014  2868

# %%
women_in_Olympics= athletes_pra[(athletes_pra.Sex == "F") & (athletes_pra.Season =="Summer")]
men_in_Olympics =athletes_pra[(athletes_pra.Sex == "M") & (athletes_pra.Season =="Summer")]

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(15,8))
sns.countplot(x='Year', data=women_in_Olympics,palette='Set1')
plt.title('Women Participation')
# Out:
# Text(0.5, 1.0, 'Women Participation')

# %%
part1 = women_in_Olympics.groupby('Year')["Sex"].value_counts()
part2 = men_in_Olympics.groupby('Year')["Sex"].value_counts()
plt.figure(figsize=(15,10))
part1.loc[:,"F"].plot()
part2.loc[:,'M'].plot()
plt.title('Graph of Athletes over time')
# Out:
# Text(0.5, 1.0, 'Graph of Athletes over time')

# %%
# details of silver athletes
silverMedals = athletes_pra[(athletes_pra.Medal == 'Silver')]
silverMedals.head()
# Out:
#      ID                Name Sex   Age  Height  Weight         Team  NOC  \
# 63   20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway  NOR
# 67   20  Kjetil Andr Aamodt   M  22.0   176.0    85.0       Norway  NOR
# 86   25    Alf Lied Aanning   M  24.0     NaN     NaN       Norway  NOR
# 92   30    Pepijn Aardewijn   M  26.0   189.0    72.0  Netherlands  NED
# 106  38        Karl Jan Aas   M  20.0     NaN     NaN       Norway  NOR
#
#            Games  Year  Season         City          Sport  \
# 63   1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 67   1994 Winter  1994  Winter  Lillehammer  Alpine Skiing
# 86   1920 Summer  1920  Summer    Antwerpen     Gymnastics
# 92   1996 Summer  1996  Summer      Atlanta         Rowing
# 106  1920 Summer  1920  Summer    Antwerpen     Gymnastics
#
#                                              Event   Medal       Region Notes
# 63                    Alpine Skiing Men's Downhill  Silver       Norway   NaN
# ...

# %%
goldMedals = athletes_pra[(athletes_pra.Medal == 'Gold')]
goldMedals.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal   Region Notes
# 3        Tug-Of-War Men's Tug-Of-War  Gold  Denmark   NaN
# ...

# %%
# no of gold medalist age>50
goldMedals = goldMedals[np.isfinite(goldMedals['Age'])]
goldMedals["ID"][goldMedals["Age"]>50].count()
# Out:
# 65

# %%
# no of silver medalist age>50
silverMedals = silverMedals[np.isfinite(silverMedals['Age'])]
silverMedals["ID"][silverMedals["Age"]>50].count()
# Out:
# 74

# %%
sporting_event_silver = silverMedals["Sport"][silverMedals["Age"]>50]
sporting_event_silver
# Out:
# 5077         Equestrianism
# 14364               Rowing
# 21999     Art Competitions
# 24898        Equestrianism
# 25131        Equestrianism
#                 ...
# 261100             Archery
# 261101             Archery
# 261677            Shooting
# 262861             Archery
# 265263    Art Competitions
# Name: Sport, Length: 74, dtype: object

# %%
sporting_event_gold = goldMedals["Sport"][goldMedals["Age"]>50]
sporting_event_gold
# Out:
# 5078         Equestrianism
# 7961               Sailing
# 13394        Equestrianism
# 13396        Equestrianism
# 24897        Equestrianism
#                 ...
# 261102             Archery
# 261671            Shooting
# 261675    Art Competitions
# 262865             Archery
# 266293    Art Competitions
# Name: Sport, Length: 65, dtype: object

# %%
# plot for sporting_event 
plt.figure(figsize=(12,8))
plt.tight_layout()
sns.countplot(sporting_event_gold)
plt.title("Gold Medals for Athletes over 50 Year")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gold Medals for Athletes over 50 Year')

# %%
# plot for sporting_event_silver
plt.figure(figsize=(12,8))
plt.tight_layout()
sns.countplot(sporting_event_silver)
plt.title("Gold Medals for Athletes over 50 Year")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gold Medals for Athletes over 50 Year')

# %%
# GOLD MEDALS FOR EACH COUNTRY 
goldMedals.Region.value_counts().reset_index(name='Medal').head(10)
# Out:
#      index  Medal
# 0      USA   2627
# 1   Russia   1599
# 2  Germany   1293
# 3       UK    657
# 4    Italy    567
# 5   France    491
# 6   Sweden    479
# 7   Canada    461
# 8  Hungary    432
# 9   Norway    378

# %%
# silver medal for differnt country
silverMedals.Region.value_counts().reset_index(name='Medal').head(10)
#bronzeMedals.Region.value_counts().reset_index(name='Medal').head(10)
# Out:
#        index  Medal
# 0        USA   1619
# 1    Germany   1176
# 2     Russia   1169
# 3         UK    684
# 4     France    563
# 5      Italy    528
# 6     Sweden    522
# 7  Australia    456
# 8     Canada    432
# 9     Norway    361

# %%
totalGoldMedals= goldMedals.Region.value_counts().reset_index(name='Medal').head(10)
g= sns.catplot(x="index",y='Medal',data= totalGoldMedals,height=6,kind="bar",palette="Spectral")
g.despine(left= True)
g.set_xlabels("Top 10 countries")
g.set_ylabels('No. of Medals')
plt.title('Gold Medals per Country')
# Out:
# Text(0.5, 1.0, 'Gold Medals per Country')

# %%
# Rio olympics
max_year = athletes_pra.Year.max()
print(max_year)

team_names = athletes_pra[(athletes_pra.Year == max_year) & (athletes_pra.Medal == "Gold")].Team
team_names.value_counts().head(20)
# Out:
# 2016
# United States    137
# Great Britain     64
# Russia            50
# Germany           47
# China             44
# Brazil            34
# Australia         23
# Argentina         21
# France            20
# Japan             17
# Denmark           15
# Serbia            14
# Fiji              13
# South Korea       13
# Hungary           12
# Jamaica           11
# Netherlands        9
# Italy              8
# Croatia            7
# Spain              7
# Name: Team, dtype: int64

# %%
# top country secure medals 
sns.barplot(x=team_names.value_counts().head(20),y=team_names.value_counts().head(20).index)
plt.ylabel(None);
plt.xlabel('Country Medals for the year 2016')
# Out:
# Text(0.5, 0, 'Country Medals for the year 2016')

# %%
# athletes which have medal 
not_null_medals = athletes_pra[(athletes_pra['Height'].notnull()) & (athletes_pra['Weight'].notnull())]

# %%
plt.figure(figsize=(12,10))
axis=sns.scatterplot(x='Height',y='Weight',data=not_null_medals,hue="Sex")
plt.title("Height vs Weight of olympic medalist")
# Out:
# Text(0.5, 1.0, 'Height vs Weight of olympic medalist')
